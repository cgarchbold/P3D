# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import seaborn as sns
import pandas as pd


attributes = ('Sign','Photo','Fire','Police','Children','Flag','Night','Shouting','Group20','Group100')

accuracies = {   'P3D':(0.869, 0.971, 0.955, 0.935, 0.968, 0.917, 0.943, 0.953, 0.652, 0.785),   
                 'P3D FT CROWD':(0.869, 0.971, 0.956, 0.937, 0.968, 0.916, 0.937, 0.953, 0.748, 0.795),
                 'P3D FT VGKG':(0.859, 0.971, 0.946, 0.930, 0.968, 0.917, 0.929, 0.953, 0.735, 0.788),
                 'Real':(0.890, 0.968, 0.979, 0.953, 0.969, 0.918, 0.936, 0.952, 0.784, 0.808) }

plt.style.use('fivethirtyeight')

SMALL_SIZE = 20
MEDIUM_SIZE = 24
BIGGER_SIZE = 28

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

aucs =  {   'P3D':(0.874,	0.576,	0.963,	0.869,	0.688,	0.735,	0.76,	0.728,	0.895,	0.515),   
                 'P3D FT(CROWD)':(	0.868,	0.562,	0.955,	0.87,	0.676,	0.758,	0.791,	0.735,	0.896,	0.65),
                 'P3D FT(VGKG)':(	0.855,	0.499,	0.959,	0.86,	0.62,	0.756,	0.785,	0.691,	0.881,	0.577),
                 "DP-SGD (ε=1)":( 0.430, 0.463, 0.483, 0.499, 0.449, 0.466, 0.509, 0.529, 0.558, 0.503),
                 "DP-SGD (ε=10)":( 0.508, 0.426, 0.566, 0.520, 0.474, 0.466, 0.510, 0.460, 0.549, 0.528),
                 'Real':(0.922,	0.817,	0.987,	0.924,	0.823,	0.816,	0.846,	0.834,	0.944,	0.851) }


x = np.arange(len(attributes))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(20,12),dpi=400)

for attribute, measurement in accuracies.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
#ax.set_title('Attribute Accuracies')
ax.set_xticks(x + width*1.5, attributes)
ax.legend(loc='upper right', ncols=4)
ax.set_ylim(0, 1.05)


plt.savefig('attribute.pdf',bbox_inches='tight', 
               transparent=True,
               pad_inches=0)
plt.show()

# %%
x = np.arange(len(attributes))  # the label locations
width = 0.125  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(30,12),dpi=400)

for attribute, measurement in aucs.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('ROC-AUC')
#ax.set_title('Attribute ROC-AUC')
ax.set_xticks(x + width*2.5, attributes)
ax.legend(loc='upper right', ncols=6, fontsize = 20)
ax.set_ylim(0, 1)


plt.savefig('auc.pdf',bbox_inches='tight', 
               transparent=True,
               pad_inches=0)
plt.show()
